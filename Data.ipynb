# %%
import pandas as pd

# %%
googleplay_reviews = pd.read_csv('tiktok_reviews.csv')

googleplay_reviews.head(10)
# Out:
#                                reviewId          userName  \
# 0  979fd0b3-6110-431d-8022-bd77c9fb81d9  Amanuel Gazehagn
# 1  0bc18aeb-65d0-41db-94ad-d8ee44d3d5ed       Waqas Ahmed
# 2  333f9bbd-a7f6-46e6-8951-d29bc21eb911  Muhammad Hussain
# 3  634661a2-91d6-435b-837e-4c2b115efabb           Md Arif
# 4  4a6c8ee1-7c62-4945-b142-a77e836a7d39       Shoukat Ali
# 5  9b2de604-452b-4a63-a6dd-424290932284      Hasib Merzae
# 6  0702f333-8531-4b1e-8a78-29443ab89882             Manii
# 7  9105b719-38d1-4c8a-b020-c7ad07fc5d06    Arsal Chaudhry
# 8  6b9fe2b0-7d3e-4964-8c0d-f5ecf022091e       Temoor Khan
# 9  0ffda3ba-84d9-46c2-bb01-f9ff3f66de62     Malik Rafique
#
#                                              content  score  thumbsUpCount  \
# 0                                           Enjoying      5              0
# 1                                          Excellent      5              0
# 2                                He is very best app      5              0
# ...

# %%
adolecent = pd.read_csv('usa_adolescent_proportion_2.csv')
adolecent.tail()
# Out:
#     Time period     Female       Male      Total
# 49         2019  12.745291  13.576482  13.157255
# 50         2020  12.683675  13.517234  13.096816
# 51         2021  12.581747  13.426138  13.000041
# 52         2022  12.477622  13.327583  12.898465
# 53         2023  12.361574  13.208904  12.780995

# %%
impulse_buying = pd.read_excel('Raw data_Impulse buying behavior.xlsx')
impulse_buying.head()
# Out:
#    SC1  SC2  SC3  SC4  SI1  SI2  SI3  SI4  SI5  TR1  ...  PP2  PP3  PP4  OIB1  \
# 0    5    5    5    5    5    3    5    3    3    5  ...    3    3    5     3
# 1    4    3    4    3    3    4    4    3    4    2  ...    3    4    3     2
# 2    4    2    2    2    3    5    4    5    3    3  ...    4    4    4     3
# 3    2    3    1    1    5    4    4    3    4    4  ...    4    4    4     2
# 4    4    4    3    3    4    4    4    4    3    5  ...    4    5    4     3
#
#    OIB2  OIB3  Q1_PROVINCE/CITY  Q2_GENDER  Q3_SCHOOL  Q4_INCOME
# 0     5     3           Can Tho          0          1          1
# 1     4     3            Ca Mau          1          1          2
# 2     2     2            Ca Mau          0          1          2
# 3     4     3         Hau Giang          1          1          1
# 4     3     3          An Giang          0          3          1
#
# [5 rows x 32 columns]

# %%
dataset1 = pd.read_csv('US_AMAZON_blackBoxProducts_1_2024-11-29.csv')
dataset1.head()
# Out:
#                                 URL        ASIN  \
# 0  https://amazon.com/dp/B07S7K5PPL  B07S7K5PPL
# 1  https://amazon.com/dp/B07RT6LDQ1  B07RT6LDQ1
# 2  https://amazon.com/dp/B00INYQ32Y  B00INYQ32Y
# 3  https://amazon.com/dp/B07PMJVZTL  B07PMJVZTL
# 4  https://amazon.com/dp/B07T2DWQVW  B07T2DWQVW
#
#                                                Title            Brand  \
# 0  Biom Probiotics Prebiotics Boric acid Supposit...  Biom Probiotics
# 1  Mr. Bird 6-Pack All Season Fruit & Nut Wild Bi...         Mr. Bird
# 2                     Fuller Brush Easy Shower Spray     Fuller Brush
# 3  120V LED Strip Light Dimmable by Wall Dimmer S...     E ENERSYSTEC
# 4  3M Command Outdoor Clear Decorating Clips Wate...          Command
#
#   Fulfillment              Category     BSR                 Subcategory  \
# 0         FBA    Health & Household   58323  Yeast Infection Treatments
# 1         FBA  Patio, Lawn & Garden   16172                   Bird Seed
# ...

# %%
strong_markets1 = dataset1[dataset1['ASIN Revenue'] > 9000:5000]


strong_markets1.head(50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 strong_markets1 = dataset1[dataset1['ASIN Revenue'] > 9000:5000]
#       4 strong_markets1.head(50)
#
# File c:\Users\Teddy\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4085, in DataFrame.__getitem__(self, key)
#    4083 # Do we have a slicer (on rows)?
#    4084 if isinstance(key, slice):
# -> 4085     return self._getitem_slice(key)
#    4087 # Do we have a (boolean) DataFrame?
#    4088 if isinstance(key, DataFrame):
#
# File c:\Users\Teddy\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:4349, in NDFrame._getitem_slice(self, key)
#    4344 """
#    4345 __getitem__ for the case where the key is a slice object.
#    4346 """
#    4347 # _convert_slice_indexer to determine if this slice is positional
# ...

# %%
strong_markets1_1 = dataset1[(dataset1['ASIN Revenue'] < 9000) & (dataset1['ASIN Revenue'] > 5000)]

strong_markets1_1.head(50)
# Out:
#                                   URL        ASIN  \
# 4    https://amazon.com/dp/B07T2DWQVW  B07T2DWQVW
# 6    https://amazon.com/dp/B07VDT1KM3  B07VDT1KM3
# 7    https://amazon.com/dp/B07WWWSPDK  B07WWWSPDK
# 11   https://amazon.com/dp/B07C51MD68  B07C51MD68
# 12   https://amazon.com/dp/B008KPZLEC  B008KPZLEC
# 17   https://amazon.com/dp/B0018NKAPI  B0018NKAPI
# 18   https://amazon.com/dp/B01MT64VBU  B01MT64VBU
# 19   https://amazon.com/dp/B00OWPYWEO  B00OWPYWEO
# 29   https://amazon.com/dp/B07HS1VSXS  B07HS1VSXS
# 34   https://amazon.com/dp/B07Q8KV2K2  B07Q8KV2K2
# 35   https://amazon.com/dp/B07P6MR57Q  B07P6MR57Q
# 36   https://amazon.com/dp/B00OTYR1F0  B00OTYR1F0
# 38   https://amazon.com/dp/B07MYPJSPF  B07MYPJSPF
# 42   https://amazon.com/dp/B01N3NX6S0  B01N3NX6S0
# 44   https://amazon.com/dp/B077BMFMZH  B077BMFMZH
# 45   https://amazon.com/dp/B00C0ZDT60  B00C0ZDT60
# 46   https://amazon.com/dp/B019IXMYL2  B019IXMYL2
# 47   https://amazon.com/dp/B00W0MJ8PE  B00W0MJ8PE
# ...
